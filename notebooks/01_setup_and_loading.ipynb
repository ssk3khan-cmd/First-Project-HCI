# %% [markdown]
# # Task 1–7: Setup, Loading, and Initial Inspection

# %%
# Task 1: Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Task 2: Load the CSV file
df = pd.read_csv("../Data/Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Task 3: Display the first few rows
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# **Student Task (Task 3):**
# - Target column: `Survived`
# - Numerical columns: `PassengerId, Survived, Pclass, Age, SibSp, Parch, Fare`
# - Categorical/text columns: `Name, Sex, Ticket, Cabin, Embarked`

# %%
# Task 4: Display random records
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 540          541         1       1            Crosby, Miss. Harriet R  female
# 309          310         1       1     Francatelli, Miss. Laura Mabel  female
# 579          580         1       3                Jussila, Mr. Eiriik    male
# 500          501         0       3                   Calic, Mr. Petar    male
# 248          249         1       1      Beckwith, Mr. Richard Leonard    male
# 873          874         0       3        Vander Cruyssen, Mr. Victor    male
# 675          676         0       3     Edvardsson, Mr. Gustaf Hjalmar    male
# 741          742         0       1      Cavendish, Mr. Tyrell William    male
# 488          489         0       3      Somerton, Mr. Francis William    male
# 684          685         0       2  Brown, Mr. Thomas William Solomon    male
#
#       Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# ...

# %%
# Task 5: General dataset information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# **Student Questions (Task 5):**
# 1. Total columns: 12
# 2. Numerical columns: PassengerId, Survived, Pclass, Age, SibSp, Parch, Fare
# 3. Text/categorical columns: Name, Sex, Ticket, Cabin, Embarked
# 4. Columns with missing values: Age (177 missing), Cabin (687 missing), Embarked (2 missing)

# %%
# Task 6: Number of rows and columns
df.shape
# Out:
# (891, 12)

# %% [markdown]
# **Student Task (Task 6):**
# Number of rows = 891
# Number of columns = 12

# %%
# Task 7: Data type of every column
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %% [markdown]
# **Student Question (Task 7):**
# - Integer (int64): PassengerId, Survived, Pclass, SibSp, Parch
# - Float (float64): Age, Fare
# - Object/text: Name, Sex, Ticket, Cabin, Embarked
